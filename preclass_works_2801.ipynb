# %% [markdown]
# <a href="https://colab.research.google.com/github/coder-omer/Pandas/blob/main/preclass_works_2801.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
series =pd.Series(['Nik', 'P', 30, 'nik@email.com', 175])

# %%
series
# Out:
# 0              Nik
# 1                P
# 2               30
# 3    nik@email.com
# 4              175
# dtype: object

# %%
dataframe1 = pd.DataFrame([('Nik', 'P', 30, 'nik@email.com', 175),
                          ('Evan', 'D', 31, 'evan@email.com')],
                          columns = ['First Name', 'Last Initial', 'Age', 'Email', 'Weight'])

# %%
dataframe1
# Out:
#   First Name Last Initial  Age           Email  Weight
# 0        Nik            P   30   nik@email.com   175.0
# 1       Evan            D   31  evan@email.com     NaN

# %%
dataframe2 = pd.DataFrame({'First Name': ['Nik', 'Evan'],
                           'Last Initial':['P','D'],
                           'Age':[30,31],
                           'Height':['nik@email.com','evan@email.com'],
                           'Weight': [175,170]})

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataframe2
# Out:
#   First Name Last Initial  Age          Height  Weight
# 0        Nik            P   30   nik@email.com     175
# 1       Evan            D   31  evan@email.com     170

# %%
df = pd.read_csv('/content/drive/MyDrive/women-stem.csv')

# %%
df
# Out:
#     Rank  Major_code  ... ShareWomen  Median
# 0      1        2419  ...   0.120564  110000
# 1      2        2416  ...   0.101852   75000
# 2      3        2415  ...   0.153037   73000
# 3      4        2417  ...   0.107313   70000
# 4      5        2418  ...   0.144967   65000
# ..   ...         ...  ...        ...     ...
# 71    72        3604  ...   0.576360   33000
# 72    73        6109  ...   0.721866   33000
# 73    74        6100  ...   0.774577   32400
# 74    75        6102  ...   0.967998   28000
# 75    76        3609  ...   0.637293   26000
#
# [76 rows x 9 columns]

# %%
df.shape
# Out:
# (76, 9)

# %%
df.head()
# Out:
#    Rank  Major_code  ... ShareWomen  Median
# 0     1        2419  ...   0.120564  110000
# 1     2        2416  ...   0.101852   75000
# 2     3        2415  ...   0.153037   73000
# 3     4        2417  ...   0.107313   70000
# 4     5        2418  ...   0.144967   65000
#
# [5 rows x 9 columns]

# %%
df.head(10)
# Out:
#    Rank  Major_code  ... ShareWomen  Median
# 0     1        2419  ...   0.120564  110000
# 1     2        2416  ...   0.101852   75000
# 2     3        2415  ...   0.153037   73000
# 3     4        2417  ...   0.107313   70000
# 4     5        2418  ...   0.144967   65000
# 5     6        2405  ...   0.341631   65000
# 6     7        5001  ...   0.535714   62000
# 7     8        2414  ...   0.119559   60000
# 8     9        2401  ...   0.139793   60000
# 9    10        2408  ...   0.196450   60000
#
# [10 rows x 9 columns]

# %%
df.tail()
# Out:
#     Rank  Major_code  ... ShareWomen Median
# 71    72        3604  ...   0.576360  33000
# 72    73        6109  ...   0.721866  33000
# 73    74        6100  ...   0.774577  32400
# 74    75        6102  ...   0.967998  28000
# 75    76        3609  ...   0.637293  26000
#
# [5 rows x 9 columns]

# %%
df.tail(10)
# Out:
#     Rank  Major_code  ... ShareWomen Median
# 66    67        4002  ...   0.864456  35000
# 67    68        6110  ...   0.792095  34000
# 68    69        3699  ...   0.556604  33500
# 69    70        6106  ...   0.566641  33500
# 70    71        3600  ...   0.601858  33400
# 71    72        3604  ...   0.576360  33000
# 72    73        6109  ...   0.721866  33000
# 73    74        6100  ...   0.774577  32400
# 74    75        6102  ...   0.967998  28000
# 75    76        3609  ...   0.637293  26000
#
# [10 rows x 9 columns]

# %%
df.head()
# Out:
#    Rank  Major_code  ... ShareWomen  Median
# 0     1        2419  ...   0.120564  110000
# 1     2        2416  ...   0.101852   75000
# 2     3        2415  ...   0.153037   73000
# 3     4        2417  ...   0.107313   70000
# 4     5        2418  ...   0.144967   65000
#
# [5 rows x 9 columns]

# %%
df.set_index('Major_code')
# Out:
#             Rank  ...  Median
# Major_code        ...
# 2419           1  ...  110000
# 2416           2  ...   75000
# 2415           3  ...   73000
# 2417           4  ...   70000
# 2418           5  ...   65000
# ...          ...  ...     ...
# 3604          72  ...   33000
# 6109          73  ...   33000
# 6100          74  ...   32400
# 6102          75  ...   28000
# 3609          76  ...   26000
#
# [76 rows x 8 columns]

# %%
df.head()
# Out:
#    Rank  Major_code  ... ShareWomen  Median
# 0     1        2419  ...   0.120564  110000
# 1     2        2416  ...   0.101852   75000
# 2     3        2415  ...   0.153037   73000
# 3     4        2417  ...   0.107313   70000
# 4     5        2418  ...   0.144967   65000
#
# [5 rows x 9 columns]

# %%
df = df.set_index('Major_code')

# %%
df.head()
# Out:
#             Rank                                      Major  ... ShareWomen  Median
# Major_code                                                   ...
# 2419           1                      PETROLEUM ENGINEERING  ...   0.120564  110000
# 2416           2             MINING AND MINERAL ENGINEERING  ...   0.101852   75000
# 2415           3                  METALLURGICAL ENGINEERING  ...   0.153037   73000
# 2417           4  NAVAL ARCHITECTURE AND MARINE ENGINEERING  ...   0.107313   70000
# 2418           5                        NUCLEAR ENGINEERING  ...   0.144967   65000
#
# [5 rows x 8 columns]

# %%
df.set_index('Major_code',inplace=True) # df tekrar eski haline döndürüldükten sonra çalıştırılıyor bu satır

# %%
df.head()
# Out:
#             Rank                                      Major  ... ShareWomen  Median
# Major_code                                                   ...
# 2419           1                      PETROLEUM ENGINEERING  ...   0.120564  110000
# 2416           2             MINING AND MINERAL ENGINEERING  ...   0.101852   75000
# 2415           3                  METALLURGICAL ENGINEERING  ...   0.153037   73000
# 2417           4  NAVAL ARCHITECTURE AND MARINE ENGINEERING  ...   0.107313   70000
# 2418           5                        NUCLEAR ENGINEERING  ...   0.144967   65000
#
# [5 rows x 8 columns]

# %%
df.Major
# Out:
# Major_code
# 2419                            PETROLEUM ENGINEERING
# 2416                   MINING AND MINERAL ENGINEERING
# 2415                        METALLURGICAL ENGINEERING
# 2417        NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 2418                              NUCLEAR ENGINEERING
#                             ...
# 3604                                          ECOLOGY
# 6109                    TREATMENT THERAPY PROFESSIONS
# 6100              GENERAL MEDICAL AND HEALTH SERVICES
# 6102    COMMUNICATION DISORDERS SCIENCES AND SERVICES
# 3609                                          ZOOLOGY
# Name: Major, Length: 76, dtype: object

# %%
df['Major']
# Out:
# Major_code
# 2419                            PETROLEUM ENGINEERING
# 2416                   MINING AND MINERAL ENGINEERING
# 2415                        METALLURGICAL ENGINEERING
# 2417        NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 2418                              NUCLEAR ENGINEERING
#                             ...
# 3604                                          ECOLOGY
# 6109                    TREATMENT THERAPY PROFESSIONS
# 6100              GENERAL MEDICAL AND HEALTH SERVICES
# 6102    COMMUNICATION DISORDERS SCIENCES AND SERVICES
# 3609                                          ZOOLOGY
# Name: Major, Length: 76, dtype: object

# %%
df.loc[2419]
# Out:
# Rank                                  1
# Major             PETROLEUM ENGINEERING
# Major_category              Engineering
# Total                              2339
# Men                                2057
# Women                               282
# ShareWomen                     0.120564
# Median                           110000
# Name: 2419, dtype: object

# %%
df.loc[2419,'Major']
# Out:
# 'PETROLEUM ENGINEERING'

# %%
df.iloc[0]
# Out:
# Rank                                  1
# Major             PETROLEUM ENGINEERING
# Major_category              Engineering
# Total                              2339
# Men                                2057
# Women                               282
# ShareWomen                     0.120564
# Median                           110000
# Name: 2419, dtype: object

# %%
df.iloc[0,1]
# Out:
# 'PETROLEUM ENGINEERING'

# %%
df.iloc[0:5]
# Out:
#             Rank                                      Major  ... ShareWomen  Median
# Major_code                                                   ...
# 2419           1                      PETROLEUM ENGINEERING  ...   0.120564  110000
# 2416           2             MINING AND MINERAL ENGINEERING  ...   0.101852   75000
# 2415           3                  METALLURGICAL ENGINEERING  ...   0.153037   73000
# 2417           4  NAVAL ARCHITECTURE AND MARINE ENGINEERING  ...   0.107313   70000
# 2418           5                        NUCLEAR ENGINEERING  ...   0.144967   65000
#
# [5 rows x 8 columns]

# %%
df.iloc[:5]
# Out:
#             Rank                                      Major  ... ShareWomen  Median
# Major_code                                                   ...
# 2419           1                      PETROLEUM ENGINEERING  ...   0.120564  110000
# 2416           2             MINING AND MINERAL ENGINEERING  ...   0.101852   75000
# 2415           3                  METALLURGICAL ENGINEERING  ...   0.153037   73000
# 2417           4  NAVAL ARCHITECTURE AND MARINE ENGINEERING  ...   0.107313   70000
# 2418           5                        NUCLEAR ENGINEERING  ...   0.144967   65000
#
# [5 rows x 8 columns]

# %%
df.iloc[-5:]
# Out:
#             Rank  ... Median
# Major_code        ...
# 3604          72  ...  33000
# 6109          73  ...  33000
# 6100          74  ...  32400
# 6102          75  ...  28000
# 3609          76  ...  26000
#
# [5 rows x 8 columns]

# %%
df.iloc[:5, :3]
# Out:
#             Rank                                      Major Major_category
# Major_code
# 2419           1                      PETROLEUM ENGINEERING    Engineering
# 2416           2             MINING AND MINERAL ENGINEERING    Engineering
# 2415           3                  METALLURGICAL ENGINEERING    Engineering
# 2417           4  NAVAL ARCHITECTURE AND MARINE ENGINEERING    Engineering
# 2418           5                        NUCLEAR ENGINEERING    Engineering

# %%
df['Major'] == 'ECOLOGY'
# Out:
# Major_code
# 2419    False
# 2416    False
# 2415    False
# 2417    False
# 2418    False
#         ...
# 3604     True
# 6109    False
# 6100    False
# 6102    False
# 3609    False
# Name: Major, Length: 76, dtype: bool

# %%
df[df['Major'] == 'ECOLOGY']
# Out:
#             Rank    Major          Major_category  ...  Women  ShareWomen  Median
# Major_code                                         ...
# 3604          72  ECOLOGY  Biology & Life Science  ...   5276     0.57636   33000
#
# [1 rows x 8 columns]

# %%
df.loc[df['Major'] == 'ECOLOGY']
# Out:
#             Rank    Major          Major_category  ...  Women  ShareWomen  Median
# Major_code                                         ...
# 3604          72  ECOLOGY  Biology & Life Science  ...   5276     0.57636   33000
#
# [1 rows x 8 columns]

# %%
df[df['ShareWomen']>.5]
# Out:
#             Rank  ... Median
# Major_code        ...
# 5001           7  ...  62000
# 6107          27  ...  48000
# 5102          29  ...  46000
# 3702          35  ...  45000
# 3607          36  ...  45000
# 6105          37  ...  45000
# 5006          38  ...  44700
# 6104          41  ...  42000
# 4006          43  ...  41000
# 3605          48  ...  40000
# 3603          49  ...  40000
# 6108          50  ...  40000
# 5003          51  ...  39000
# 3606          52  ...  38000
# 3601          54  ...  37400
# 3602          55  ...  37000
# 5005          58  ...  36000
# 6199          59  ...  36000
# 1301          60  ...  35600
# 5098          63  ...  35000
# 3608          64  ...  35000
# 3611          65  ...  35000
# 6103          66  ...  35000
# 4002          67  ...  35000
# 6110          68  ...  34000
# 3699          69  ...  33500
# 6106          70  ...  33500
# 3600          71  ...  33400
# 3604          72  ...  33000
# 6109          73  ...  33000
# ...

# %%
df[(df['ShareWomen']>.5) & (df['Major_category'] =='Biology & Life Science')]
# Out:
#             Rank                                Major  ... ShareWomen  Median
# Major_code                                             ...
# 3607          36                         PHARMACOLOGY  ...   0.707719   45000
# 4006          43  COGNITIVE SCIENCE AND BIOPSYCHOLOGY  ...   0.564866   41000
# 3605          48                             GENETICS  ...   0.515543   40000
# 3603          49                    MOLECULAR BIOLOGY  ...   0.594208   40000
# 3606          52                         MICROBIOLOGY  ...   0.580948   38000
# 3601          54                 BIOCHEMICAL SCIENCES  ...   0.515406   37400
# 3602          55                               BOTANY  ...   0.528969   37000
# 1301          60                ENVIRONMENTAL SCIENCE  ...   0.584556   35600
# 3608          64                           PHYSIOLOGY  ...   0.618223   35000
# 3611          65                         NEUROSCIENCE  ...   0.638147   35000
# ...

# %%
df[(df['Major_category'] =='Health') | (df['Major_category'] =='Biology & Life Science')]
# Out:
#             Rank  ... Median
# Major_code        ...
# 6107          27  ...  48000
# 3607          36  ...  45000
# 6105          37  ...  45000
# 6104          41  ...  42000
# 4006          43  ...  41000
# 3605          48  ...  40000
# 3603          49  ...  40000
# 6108          50  ...  40000
# 3606          52  ...  38000
# 3601          54  ...  37400
# 3602          55  ...  37000
# 6199          59  ...  36000
# 1301          60  ...  35600
# 3608          64  ...  35000
# 3611          65  ...  35000
# 6103          66  ...  35000
# 4002          67  ...  35000
# 6110          68  ...  34000
# 3699          69  ...  33500
# 6106          70  ...  33500
# 3600          71  ...  33400
# 3604          72  ...  33000
# 6109          73  ...  33000
# 6100          74  ...  32400
# 6102          75  ...  28000
# 3609          76  ...  26000
#
# [26 rows x 8 columns]

# %%
df[df['Major_category'].isin(['Health','Biology & Life Science'])]
# Out:
#             Rank  ... Median
# Major_code        ...
# 6107          27  ...  48000
# 3607          36  ...  45000
# 6105          37  ...  45000
# 6104          41  ...  42000
# 4006          43  ...  41000
# 3605          48  ...  40000
# 3603          49  ...  40000
# 6108          50  ...  40000
# 3606          52  ...  38000
# 3601          54  ...  37400
# 3602          55  ...  37000
# 6199          59  ...  36000
# 1301          60  ...  35600
# 3608          64  ...  35000
# 3611          65  ...  35000
# 6103          66  ...  35000
# 4002          67  ...  35000
# 6110          68  ...  34000
# 3699          69  ...  33500
# 6106          70  ...  33500
# 3600          71  ...  33400
# 3604          72  ...  33000
# 6109          73  ...  33000
# 6100          74  ...  32400
# 6102          75  ...  28000
# 3609          76  ...  26000
#
# [26 rows x 8 columns]

# %%
drinks = pd.read_csv('http://bit.ly/drinksbycountry')

# %%
drinks.head()
# Out:
#        country  beer_servings  ...  total_litres_of_pure_alcohol  continent
# 0  Afghanistan              0  ...                           0.0       Asia
# 1      Albania             89  ...                           4.9     Europe
# 2      Algeria             25  ...                           0.7     Africa
# 3      Andorra            245  ...                          12.4     Europe
# 4       Angola            217  ...                           5.9     Africa
#
# [5 rows x 6 columns]

# %%
drinks.beer_servings.mean()
# Out:
# 106.16062176165804

# %%
drinks.groupby('continent').beer_servings.mean()
# Out:
# continent
# Africa            61.471698
# Asia              37.045455
# Europe           193.777778
# North America    145.434783
# Oceania           89.687500
# South America    175.083333
# Name: beer_servings, dtype: float64

# %%
drinks[drinks.continent=='Africa'].beer_servings.mean()
# Out:
# 61.471698113207545

# %%
drinks.groupby('continent').beer_servings.max()
# Out:
# continent
# Africa           376
# Asia             247
# Europe           361
# North America    285
# Oceania          306
# South America    333
# Name: beer_servings, dtype: int64

# %%
drinks.groupby('continent').beer_servings.min()
# Out:
# continent
# Africa            0
# Asia              0
# Europe            0
# North America     1
# Oceania           0
# South America    93
# Name: beer_servings, dtype: int64

# %%
drinks.groupby('continent').beer_servings.agg(['count','min','max','mean'])
# Out:
#                count  min  max        mean
# continent
# Africa            53    0  376   61.471698
# Asia              44    0  247   37.045455
# Europe            45    0  361  193.777778
# North America     23    1  285  145.434783
# Oceania           16    0  306   89.687500
# South America     12   93  333  175.083333

# %%
drinks.groupby('continent').mean()
# Out:
#                beer_servings  ...  total_litres_of_pure_alcohol
# continent                     ...
# Africa             61.471698  ...                      3.007547
# Asia               37.045455  ...                      2.170455
# Europe            193.777778  ...                      8.617778
# North America     145.434783  ...                      5.995652
# Oceania            89.687500  ...                      3.381250
# South America     175.083333  ...                      6.308333
#
# [6 rows x 4 columns]

# %%
drinks.groupby('continent')['country'].count()
# Out:
# continent
# Africa           53
# Asia             44
# Europe           45
# North America    23
# Oceania          16
# South America    12
# Name: country, dtype: int64

# %%
# %matplotlib inline

# %%
drinks.groupby('continent').mean().plot(kind='bar')

# %% [markdown]
# Aggregation

# %%
df.head()
# Out:
#             Rank                                      Major  ... ShareWomen  Median
# Major_code                                                   ...
# 2419           1                      PETROLEUM ENGINEERING  ...   0.120564  110000
# 2416           2             MINING AND MINERAL ENGINEERING  ...   0.101852   75000
# 2415           3                  METALLURGICAL ENGINEERING  ...   0.153037   73000
# 2417           4  NAVAL ARCHITECTURE AND MARINE ENGINEERING  ...   0.107313   70000
# 2418           5                        NUCLEAR ENGINEERING  ...   0.144967   65000
#
# [5 rows x 8 columns]

# %%
data = [['tom', 10], ['nick', 15], ['juli', 14]]
df2 = pd.DataFrame(data, columns=['Name', 'Age'])

# %%
df2
# Out:
#    Name  Age
# 0   tom   10
# 1  nick   15
# 2  juli   14

# %%
df2['Sex'] = ['male','male','female']

# %%
df2
# Out:
#    Name  Age     Sex
# 0   tom   10    male
# 1  nick   15    male
# 2  juli   14  female

# %%
df2['protected'] = ['no', 'no', 'yes']
df2
# Out:
#    Name  Age     Sex protected
# 0   tom   10    male        no
# 1  nick   15    male        no
# 2  juli   14  female       yes

# %%
df2['key'] =  ['1','2','3']
df2
# Out:
#    Name  Age     Sex protected key
# 0   tom   10    male        no   1
# 1  nick   15    male        no   2
# 2  juli   14  female       yes   3

# %%
df2
# Out:
#    Name  Age     Sex protected key
# 0   tom   10    male        no   1
# 1  nick   15    male        no   2
# 2  juli   14  female       yes   3

# %%
df2.loc[-1] = ['ali',25,'male','yes',4]
df2.index = df2.index+1
df2 = df2.sort_index()

# %%
df2
# Out:
#    Name  Age     Sex protected key
# 0   ali   25    male       yes   4
# 1   tom   10    male        no   1
# 2  nick   15    male        no   2
# 3  juli   14  female       yes   3

# %%
df2 = df2.append({'Name' : 'veli',
                  'Age' : '22',
                  'Sex': 'male',
                  'protected':'no',
                  'key' :'4'},
                 ignore_index=True)

# %%
df2
# Out:
#    Name Age     Sex protected key
# 0   ali  25    male       yes   4
# 1   tom  10    male        no   1
# 2  nick  15    male        no   2
# 3  juli  14  female       yes   3
# 4  veli  22    male        no   4

# %%
df2 = df2.append({'Name' : 'hadi',
                  'Age' : '41',
                  'Sex': 'male',
                  'protected':'no',
                  'key' :'2'},
                 ignore_index=True)

# %%
df2 = df2.append({'Name' : 'selen',
                  'Age' : '19',
                  'Sex': 'female',
                  'protected':'yes',
                  'key' :'3'},
                 ignore_index=True)

# %%
df2
# Out:
#     Name Age     Sex protected key
# 0    ali  25    male       yes   4
# 1    tom  10    male        no   1
# 2   nick  15    male        no   2
# 3   juli  14  female       yes   3
# 4   veli  22    male        no   4
# 5   hadi  41    male        no   2
# 6  selen  19  female       yes   3

# %%
df2.loc[7] = ['Smriti', 26, 'male', 'yes',1]

# %%
df2
# Out:
#      Name Age     Sex protected key
# 0     ali  25    male       yes   4
# 1     tom  10    male        no   1
# 2    nick  15    male        no   2
# 3    juli  14  female       yes   3
# 4    veli  22    male        no   4
# 5    hadi  41    male        no   2
# 6   selen  19  female       yes   3
# 7  Smriti  26    male       yes   1

# %%
df2.iloc[3] = ['Dimitri', 80, 'male', 'yes',1]
df2
# Out:
#       Name Age     Sex protected key
# 0      ali  25    male       yes   4
# 1      tom  10    male        no   1
# 2     nick  15    male        no   2
# 3  Dimitri  80    male       yes   1
# 4     veli  22    male        no   4
# 5     hadi  41    male        no   2
# 6    selen  19  female       yes   3
# 7   Smriti  26    male       yes   1

# %%
df3 = pd.DataFrame({'key': ['A','B','C','A','B','C'],
                    'data':range(6)},
                   columns = ['key','data']
                   )

# %%
df3
# Out:
#   key  data
# 0   A     0
# 1   B     1
# 2   C     2
# 3   A     3
# 4   B     4
# 5   C     5

# %%
df3.groupby('key').sum()
# Out:
#      data
# key
# A       3
# B       5
# C       7

# %%
df3=df3.rename(columns = {'data':'data1'})
df3
# Out:
#   key  data1
# 0   A      0
# 1   B      1
# 2   C      2
# 3   A      3
# 4   B      4
# 5   C      5
